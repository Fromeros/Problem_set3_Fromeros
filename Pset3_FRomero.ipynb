# %% [markdown]
# # Problem set 3
#
# # Script´s Author: Fabian Romero
#
# The following book shows the water level observations at
# **Cedar Key, FL, from 9/26/2024 to 9/27/2024** during the landfall of Hurricane Helene.
#
# Here you can find the followind data set **CO-OPS_8727520_wl.csv**
#
# The columns are fairly self-explanatory:
#
# * Date
# * Time (GMT)
# * Predicted (ft): Predicted tide level
# * Preliminary (ft): Observed tide level, preliminary data
# * Verified (ft): No verified data when downloaded

# %% [markdown]
# # Problem 1 (5 pts):
#
# Write a script (or Jupyter Notebook code block) that opens the file, uses a for loop to read through the file line by line and, after finishing reading through the file, reports the **highest water level and the date and time** that was observed.

# %%
# Answer Problem 1

# Open file name

import csv

cedar_key_water = 'CO-OPS_8727520_wl.csv'

# track the highest water level and its corresponding date and time
highest_level = float('-inf')
highest_level_time = ''

# Open the CSV file and read it
with open(cedar_key_water, mode='r') as file:
    csv_reader = csv.DictReader(file)
    
    for row in csv_reader:
        date = row['Date']
        time = row['Time (GMT)']
        observed_level = float(row['Preliminary (ft)'])
        
        # Checking the if the observed water level is the highest 
        if observed_level > highest_level:
            highest_level = observed_level
            highest_level_time = f'{date} {time}'

# Reporting the highest water level and the date and time it was observed
print(f"What is the highest water level and when did it occur?")
print("")
print(f'The highest water level observed was {highest_level} feet at {highest_level_time}.')
# Out:
# What is the highest water level and when did it occur?
#
# The highest water level observed was 13.1 feet at 2024/09/27 04:42.

# %% [markdown]
# # Problem 2 (5 pts):
#
# Either in a new script or modifying the above script, calculate the **lowest, highest and average** water level observed during the time period. As above, **print the date and time for the lowest and highest readings**.

# %%
# Answer Problem 2

import csv

cedar_key_water = 'CO-OPS_8727520_wl.csv'

# track the highest and lowest water level and its corresponding date and time
highest_level = float('-inf')
lowest_level = float('inf')
highest_level_time = ''
lowest_level_time = ''
total_level = 0
count = 0

# Open the CSV file and read it
with open(cedar_key_water, mode='r') as file:
    csv_reader = csv.DictReader(file)
    
    for row in csv_reader:
        date = row['Date']
        time = row['Time (GMT)']
        observed_level = float(row['Preliminary (ft)'])
        
        # Checking the if the observed water level is the highest 
        if observed_level > highest_level:
            highest_level = observed_level
            highest_level_time = f'{date} {time}'
            
        # Checking the if the observed water level is the lowest 
        if observed_level < lowest_level:
            lowest_level = observed_level
            lowest_level_time = f'{date} {time}'
            
   # total water level and number of observations
        total_level += observed_level
        count += 1

# average water level
average_level = total_level / count if count != 0 else 0

# Reporting the highest, lowest and average water level and the date and time it was observed
print(f"What is the highest water level and when did it occur?")
print("")
print(f'The highest water level observed was {highest_level} feet at {highest_level_time}.')
print("")
print(f"What is the lowest water level and when did it occur?")
print("")
print(f'The lowest water level observed was {lowest_level} feet at {lowest_level_time}.')
print("")
print(f"What is the average water level?")
print("")
print(f'The average water level observed was {average_level:.2f} feet.')
# Out:
# What is the highest water level and when did it occur?
#
# The highest water level observed was 13.1 feet at 2024/09/27 04:42.
#
# What is the lowest water level and when did it occur?
#
# The lowest water level observed was 1.53 feet at 2024/09/27 23:00.
#
# What is the average water level?
#
# The average water level observed was 5.68 feet.

# %% [markdown]
# # Problem 3 (5 pts):
#
# Write a script (or Jupyter Notebook) that calculates the **fastest rise in water level per 6-minute period between measurements** (for this assignment, assume that each line of the dataset is a 6-minute interval) and reports the **date and time** that was observed and the change in water level from the previous recording.

# %%
#Answer Problem 3

import csv

cedar_key_water = 'CO-OPS_8727520_wl.csv'

# tracking the fastest rise in water levels and its corresponding date and time
fastest_rise = float("-inf")
fastest_rise_time = ""
previous_record = None

#Open the file and read it
with open (cedar_key_water, mode ="r") as file:
    csv_reader = csv.DictReader(file)
    
    for row in csv_reader:
        date = row["Date"]
        time = row["Time (GMT)"]
        observed_level = float(row["Preliminary (ft)"])
        
        #Rise in level water from previous records
        if previous_record is not None:
            rise = observed_level - previous_record
            
            #Checking the fastest rise in water level
            if rise > fastest_rise:
                fastest_rise = rise
                fastest_rise_time = f"{date} {time}"
                
        #Checking the current rise level
        previous_record = observed_level
                

# Reporting the fastest rise in water level and the date and time it was observed
print(f"What is the fastest rise in water level and when did it occur?")
print("")
print(f'The fastest rise in water level observed was {fastest_rise:.2f} feet at {fastest_rise_time}.')
# Out:
# What is the fastest rise in water level and when did it occur?
#
# The fastest rise in water level observed was 0.61 feet at 2024/09/27 01:12.

# %% [markdown]
# # Problem 4 (5 pts):
#
# Imagine that the file is providing live readings of the water level. Write a script (or Jupyter Notebook) to print a **line of text with a warning if any of these events occur**:
#
# * The water level increases more than 0.25 since the previous recording.
# * The water level is over 5.0.
# * No reading is received at a time point.

# %%
#Answer Problem 4

import csv

cedar_key_water = 'CO-OPS_8727520_wl.csv'

#Tracking previous record fo water levels

previous_records = None

#Open the file and read it
with open(cedar_key_water, mode='r') as file:
    csv_reader = csv.DictReader(file)
    
    for row in csv_reader:
        date = row['Date']
        time = row['Time (GMT)']
        observed_level = row['Preliminary (ft)']
        
        #Checking if the reading is received or not
        if observed_level == "":
            print(f"WARNING!!!: No reading received at {date} {time}.")
            continue
            
        observed_level = float(observed_level)
        
        #Checking if the water level is increases more than 0.25 feet since the previous records
        if previous_records is not None and (observed_level - previous_records) > 0.25:
            print(f"WARNING!!!: The water level increased more than 0.25 feet at {date} {time}.")
            
        #Cheking if the water level is over 0.50 feet
        if observed_level > 5.0:
            print(f"WARNING!!!: The water level is over 5.0 feet at {date} {time}.")
            
        #Checking the current rise level
        previous_records = observed_level
# Out:
# WARNING!!!: The water level increased more than 0.25 feet at 2024/09/26 01:24.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 10:00.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 10:06.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 10:54.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:00.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:06.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:12.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:36.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:42.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:48.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 11:54.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 12:00.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 12:06.
# WARNING!!!: The water level is over 5.0 feet at 2024/09/26 12:12.
# ...
